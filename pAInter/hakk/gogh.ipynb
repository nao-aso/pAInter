# %%
cd  C:\hakkason\hakk\hakk
# Out:
# C:\hakkason\hakk\hakk
# c:\hakkason\venv\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !ls
# Out:
# 'ls' �́A�����R�}���h�܂��͊O���R�}���h�A
# ����\�ȃv���O�����܂��̓o�b�` �t�@�C���Ƃ��ĔF������Ă��܂���B

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# fatal: destination path 'pytorch-CycleGAN-and-pix2pix' already exists and is not an empty directory.

# %%
cd pytorch-CycleGAN-and-pix2pix
# Out:
# C:\hakkason\hakk\hakk\pytorch-CycleGAN-and-pix2pix

# %%
# !pip install -r requirements.txt

# %%
# !bash ./scripts/download_cyclegan_model.sh style_ukiyoe
# !bash ./scripts/download_cyclegan_model.sh style_monet
# !bash ./scripts/download_cyclegan_model.sh style_cezanne
# !bash ./scripts/download_cyclegan_model.sh style_vangogh
# Out:
# Note: available models are apple2orange, orange2apple, summer2winter_yosemite, winter2summer_yosemite, horse2zebra, zebra2horse, monet2photo, style_monet, style_cezanne, style_ukiyoe, style_vangogh, sat2map, map2sat, cityscapes_photo2label, cityscapes_label2photo, facades_photo2label, facades_label2photo, iphone2dslr_flower
# Specified [style_ukiyoe]
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2024-06-18 12:33:09--  http://efrosgans.eecs.berkeley.edu/cyclegan/pretrained_models/style_ukiyoe.pth
# Resolving efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)... 128.32.244.190
# Connecting to efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)|128.32.244.190|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45575747 (43M)
# Saving to: ‘./checkpoints/style_ukiyoe_pretrained/latest_net_G.pth’
#
#      0K .......... .......... .......... .......... ..........  0%  167K 4m26s
# ...

# %%
# !pip install dominate
# !pip install torch torchvision
# !pip install --upgrade torch torchvision

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...

# %%
# !python C:\hakkason\hakk\hakk\pytorch-CycleGAN-and-pix2pix\test.py --dataroot C:\hakkason\hakk\hakk\datasets\testA --name style_ukiyoe_pretrained --model test --no_dropout --gpu_ids -1
# !python C:\hakkason\hakk\hakk\pytorch-CycleGAN-and-pix2pix\test.py --dataroot C:\hakkason\hakk\hakk\datasets\testA --name style_monet_pretrained --model test --no_dropout --gpu_ids -1
# !python C:\hakkason\hakk\hakk\pytorch-CycleGAN-and-pix2pix\test.py --dataroot C:\hakkason\hakk\hakk\datasets\testA --name style_cezanne_pretrained --model test --no_dropout --gpu_ids -1
# !python C:\hakkason\hakk\hakk\pytorch-CycleGAN-and-pix2pix\test.py --dataroot C:\hakkason\hakk\hakk\datasets\testA --name style_vangogh_pretrained --model test --no_dropout --gpu_ids -1
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: C:\hakkason\hakk\hakk\datasets\testA	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: -1                            	[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
# ...

# %%
cd pytorch-CycleGAN-and-pix2pix
# Out:
# d:\hakk\hakk\pytorch-CycleGAN-and-pix2pix
# C:\Users\Owner\AppData\Roaming\Python\Python310\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip uninstall numpy

# %%
# !pip install numpy<2

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.0.0

# %%
# !pip install numpy==1.24.3
# Out:
# ...
#      --------------------------------------- 14.8/14.8 MB 50.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.0
#     Uninstalling numpy-2.0.0:
#       Successfully uninstalled numpy-2.0.0
# ERROR: Could not install packages due to an OSError: [WinError 5] アクセスが拒否されました。: 'C:\\Users\\Owner\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\~umpy.libs\\libscipy_openblas64_-fb1711452d4d8cee9f276fd1449ee5c7.dll'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip show torchvision
# Out:
# Name: torchvision
# Version: 0.18.1
# Summary: image and video datasets and models for torch deep learning
# Home-page: https://github.com/pytorch/vision
# Author: PyTorch Core Team
# Author-email: soumith@pytorch.org
# License: BSD
# Location: c:\hakkason\venv\lib\site-packages
# Requires: numpy, pillow, torch
# Required-by:

# %%
# !pip show torch
# Out:
# Name: torch
# Version: 2.3.1+cu121
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: c:\hakkason\venv\lib\site-packages
# Requires: filelock, fsspec, jinja2, mkl, networkx, sympy, typing-extensions
# Required-by: torchaudio, torchvision
