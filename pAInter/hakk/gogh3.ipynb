# %%
cd C:\Users\amay2\Downloads\hakk-20240617T135459Z-001\hakk\pytorch-CycleGAN-and-pix2pix
# Out:
# C:\Users\amay2\Downloads\hakk-20240617T135459Z-001\hakk\pytorch-CycleGAN-and-pix2pix

# %%
# !pip install dominate
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: C:\Users\amay2\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !python test.py --dataroot C:\Users\amay2\Downloads\hakk-20240617T135459Z-001\hakk\datasets\testA --name style_ukiyoe_pretrained --model test --no_dropout --gpu_ids -1
# !python test.py --dataroot C:\Users\amay2\Downloads\hakk-20240617T135459Z-001\hakk\datasets\testA --name style_monet_pretrained --model test --no_dropout --gpu_ids -1
# !python test.py --dataroot C:\Users\amay2\Downloads\hakk-20240617T135459Z-001\hakk\datasets\testA --name style_cezanne_pretrained --model test --no_dropout --gpu_ids -1
# !python test.py --dataroot C:\Users\amay2\Downloads\hakk-20240617T135459Z-001\hakk\datasets\testA --name style_vangogh_pretrained --model test --no_dropout --gpu_ids -1
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: C:\Users\amay2\Downloads\hakk-20240617T135459Z-001\hakk\datasets\testA	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: -1                            	[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
# ...
